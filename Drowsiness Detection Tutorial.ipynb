# %% [markdown]
# # 1. Install and Import Dependencies

# %%
pip3 install torch torchvision torchaudio
# Out:
# ...
#   Using cached torchvision-0.14.0-cp39-cp39-win_amd64.whl (1.1 MB)
# ...
#      ---------------------------------------- 2.1/2.1 MB 24.4 kB/s eta 0:00:00
# ...
#   Using cached Pillow-9.3.0-cp39-cp39-win_amd64.whl (2.5 MB)
# ...

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
# !cd yolov5 & pip install -r requirements.txt
# Out:
# ...
#   Using cached matplotlib-3.6.2-cp39-cp39-win_amd64.whl (7.2 MB)
# ...
#   Using cached PyYAML-6.0-cp39-cp39-win_amd64.whl (151 kB)
# ...
#   Using cached tensorboard-2.11.0-py3-none-any.whl (6.0 MB)
# ...
#   Using cached seaborn-0.12.1-py3-none-any.whl (288 kB)
# ...
#   Using cached kiwisolver-1.4.4-cp39-cp39-win_amd64.whl (55 kB)
# ...
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# ...
#   Using cached contourpy-1.0.6-cp39-cp39-win_amd64.whl (161 kB)
# ...
#   Using cached fonttools-4.38.0-py3-none-any.whl (965 kB)
# ...
#   Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# ...
#      ---------------------------------------- 3.7/3.7 MB 123.8 kB/s eta 0:00:00
# ...
#   Using cached Markdown-3.4.1-py3-none-any.whl (93 kB)
# ...
#   Using cached Werkzeug-2.2.2-py3-none-any.whl (232 kB)
# ...
#   Using cached wheel-0.38.4-py3-none-any.whl (36 kB)
# ...
#   Using cached absl_py-1.3.0-py3-none-any.whl (124 kB)
# ...
#   Using cached tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
# ...

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %% [markdown]
# # 2. Load Model

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
# Out:
# Using cache found in C:\Users\mrunali/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2022-11-20 Python-3.9.9 torch-1.13.0+cpu CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...

# %%
# Out:
# [67]

# %%
model
# Out:
# AutoShape(
#   (model): DetectMultiBackend(
#     (model): DetectionModel(
#       (model): Sequential(
#         (0): Conv(
#           (conv): Conv2d(3, 32, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (2): C3(
#           (cv1): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
# ...

# %% [markdown]
# # 3. Make Detections with Images

# %%
img = 'https://ultralytics.com/images/zidane.jpg'

# %%
results = model(img)
results.print()
# Out:
# image 1/1: 720x1280 2 persons, 2 ties
# Speed: 1676.3ms pre-process, 915.9ms inference, 15.6ms NMS per image at shape (1, 3, 384, 640)

# %%
type(results)
# Out:
# models.common.Detections

# %%
results.print()
# Out:
# image 1/1: 720x1280 2 persons, 2 ties
# Speed: 1676.3ms pre-process, 915.9ms inference, 15.6ms NMS per image at shape (1, 3, 384, 640)

# %%
# %matplotlib inline 
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
print(np.squeeze(results.render()))
# Out:
# [[[72 48 38]
#   [74 50 40]
#   [73 51 40]
#   ...
#   [56 21 25]
#   [55 19 21]
#   [51 15 17]]
#
#  [[71 47 37]
#   [71 47 37]
#   [70 48 37]
#   ...
#   [55 20 24]
#   [52 16 18]
#   [47 11 13]]
#
#  [[75 51 41]
#   [73 49 39]
#   [70 48 37]
#   ...
#   [56 20 24]
#   [52 16 20]
#   [48 12 16]]
#
#  ...
#
#  [[40 43 48]
#   [41 44 49]
#   [40 43 48]
#   ...
#   [35 49 49]
#   [35 49 49]
#   [36 50 50]]
#
#  [[39 42 49]
#   [39 42 49]
#   [39 42 49]
#   ...
#   [35 49 50]
#   [35 49 50]
#   [36 50 51]]
#
#  [[38 41 48]
#   [38 41 48]
#   [38 41 48]
#   ...
#   [35 49 50]
#   [35 49 50]
#   [36 50 51]]]

# %% [markdown]
# # 4. Real Time Detections

# %%
pip install thread6
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from threading import Thraed 
from functools import partial
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 from threading import Thraed
#       2 from functools import partial
#
# ImportError: cannot import name 'Thraed' from 'threading' (C:\Python\Python39\lib\threading.py)

# %%
import multiprocessing
from multiprocessing import Process

def loop_a():

    while True:
        

        print("a")

def loop_b():

    while True:
        
        print("b")

if __name__ == '__main__':
   

    Process(target=loop_a).start()
   
    Process(target=loop_b).start()

# %%
import winsound
frequency = 2500  # Set Frequency To 2500 Hertz
duration = 1000  # Set Duration To 1000 ms == 1 second

cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    
    # Make detections
    results = model(frame)
    print(results.xywh[0])
    dclass=results.xywh[0][0][5]
    dconf=results.xywh[0][0][4]
    print(dclass)
    print(dclass.item())
    print(type(dclass))
    print
    cv2.imshow('YOLO', np.squeeze(results.render()))
    if (dconf<=70) and (dclass.item()==6.70000e+01 or dclass.item()==67.00000):
        winsound.Beep(frequency, duration)
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# tensor([[3.25179e+02, 3.43595e+02, 2.17431e+02, 2.67978e+02, 7.47528e-01, 0.00000e+00],
#         [5.29346e+02, 2.39266e+02, 2.15746e+02, 4.71522e+02, 4.01336e-01, 7.20000e+01]])
# tensor(0.)
# 0.0
# <class 'torch.Tensor'>
# tensor([[3.38756e+02, 3.82320e+02, 1.92324e+02, 1.94611e+02, 7.21672e-01, 0.00000e+00],
#         [5.29373e+02, 2.39542e+02, 2.17211e+02, 4.77074e+02, 3.65152e-01, 7.20000e+01]])
# tensor(0.)
# 0.0
# <class 'torch.Tensor'>
# tensor([[3.41882e+02, 3.45284e+02, 2.11899e+02, 2.66304e+02, 6.21152e-01, 0.00000e+00],
#         [3.42352e+02, 3.44935e+02, 2.13818e+02, 2.66560e+02, 4.90520e-01, 1.60000e+01],
#         [5.29668e+02, 2.39468e+02, 2.17192e+02, 4.72034e+02, 4.18672e-01, 7.20000e+01]])
# tensor(0.)
# 0.0
# <class 'torch.Tensor'>
# tensor([[340.48444, 358.78448, 194.71632, 242.43100,   0.66592,  16.00000]])
# tensor(16.)
# 16.0
# <class 'torch.Tensor'>
# tensor([[3.54983e+02, 3.38935e+02, 2.22830e+02, 2.80057e+02, 7.62546e-01, 0.00000e+00],
# ...

# %% [markdown]
# # TIMER

# %%
import time
import pyttsx3
main_ctr=0
ctr=0
engine = pyttsx3.init()
engine.say("Your pomodoro has began")
engine.runAndWait()
print("Your pomodoro has began")
while True:
  while (ctr==0 or ctr%4!=0):
    print("Get to work")
    engine.say("Get to work")
    engine.runAndWait()
    time.sleep(10)
    ctr=ctr+1
    if(ctr%4!=0):

      print("take 5 seconds break")
      engine.say("take 5 seconds break")
      engine.runAndWait()

      time.sleep(5)
    else:
      print("take 20 seconds break")
      engine.say("take 20 seconds break")
      engine.runAndWait()
  time.sleep(20)
  main_ctr=main_ctr+1
  print(main_ctr," pomodoro completed")
  engine.say(" pomodoro completed")
  engine.runAndWait()
  ctr=0
# Out:
# Your pomodoro has began
# Get to work
# take 5 seconds break
# Get to work
# take 5 seconds break
# Get to work
# take 5 seconds break
# Get to work
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 14
#      12 engine.say("Get to work")
#      13 engine.runAndWait()
# ---> 14 time.sleep(10)
#      15 ctr=ctr+1
#      16 if(ctr%4!=0):
#
# KeyboardInterrupt:

# %% [markdown]
# # 5. Train from scratch

# %%
import uuid   # Unique identifier
import os
import time

# %%
IMAGES_PATH = os.path.join('data', 'images') #/data/images
labels = ['awake', 'drowsy']
number_imgs = 5

# %%
cap = cv2.VideoCapture(0)
# Loop through labels
for label in labels:
    print('Collecting images for {}'.format(label))
    time.sleep(5)
    
    # Loop through image range
    for img_num in range(number_imgs):
        print('Collecting images for {}, image number {}'.format(label, img_num))
        
        # Webcam feed
        ret, frame = cap.read()
        
        # Naming out image path
        imgname = os.path.join(IMAGES_PATH, label+'.'+str(uuid.uuid1())+'.jpg')
        
        # Writes out image to file 
        cv2.imwrite(imgname, frame)
        
        # Render to the screen
        cv2.imshow('Image Collection', frame)
        
        # 2 second delay between captures
        time.sleep(2)
        
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
cap.release()
cv2.destroyAllWindows()

# %%
print(os.path.join(IMAGES_PATH, labels[0]+'.'+str(uuid.uuid1())+'.jpg'))

# %%
for label in labels:
    print('Collecting images for {}'.format(label))
    for img_num in range(number_imgs):
        print('Collecting images for {}, image number {}'.format(label, img_num))
        imgname = os.path.join(IMAGES_PATH, label+'.'+str(uuid.uuid1())+'.jpg')
        print(imgname)

# %%
# !git clone https://github.com/tzutalin/labelImg

# %%
# !pip install pyqt5 lxml --upgrade
# !cd labelImg && pyrcc5 -o libs/resources.py resources.qrc

# %%
# !cd yolov5 && python train.py --img 320 --batch 16 --epochs 500 --data dataset.yml --weights yolov5s.pt --workers 2

# %% [markdown]
# # 6. Load Custom Model

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path='yolov5/runs/train/exp15/weights/last.pt', force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/archive/master.zip" to C:\Users\User/.cache\torch\hub\master.zip
# YOLOv5  2021-7-11 torch 1.8.1+cu111 CUDA:0 (GeForce RTX 2070 SUPER, 8192.0MB)
#
# Fusing layers...
# Model Summary: 224 layers, 7097062 parameters, 0 gradients, 16.5 GFLOPs
# Adding AutoShape...

# %%
img = os.path.join('data', 'images', 'awake.c9a24d48-e1f6-11eb-bbef-5cf3709bbcc6.jpg')

# %%
results = model(img)

# %%
results.print()
# Out:
# image 1/1: 480x640 1 awake
# Speed: 16.0ms pre-process, 11.0ms inference, 2.0ms NMS per image at shape (1, 3, 480, 640)

# %%
# %matplotlib inline 
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    
    # Make detections 
    results = model(frame)
    
    cv2.imshow('YOLO', np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
